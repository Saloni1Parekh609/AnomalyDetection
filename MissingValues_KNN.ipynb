# %%
# !pip install -U scikit-learn
# Out:
# ...
#      |████████████████████████████████| 7.2 MB 3.1 MB/s eta 0:00:01
# ...
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# ...
# ERROR: simpletransformers 0.28.5 has requirement transformers>=2.9.1, but you'll have transformers 2.1.1 which is incompatible.
# ERROR: cdqa 1.3.9 has requirement scikit-learn==0.21.2, but you'll have scikit-learn 0.23.1 which is incompatible.
# ERROR: cdqa 1.3.9 has requirement torch==1.2.0, but you'll have torch 1.5.1 which is incompatible.
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.21.2
#     Uninstalling scikit-learn-0.21.2:
#       Successfully uninstalled scikit-learn-0.21.2
# ...
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/Users/saloniparekh/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Last_89_ANNFormat.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Country Name  Year  \
# 0       11160             0     Pakistan  1960
# 1       11161             0     Pakistan  1961
# 2       11162             0     Pakistan  1962
# 3       11163             0     Pakistan  1963
# 4       11164             0     Pakistan  1964
#
#   ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of population)  \
# 0                                      ..
# 1                                      ..
# 2                                      ..
# 3                                      ..
# 4                                      ..
#
#   Adjusted net national income (annual % growth)  \
# ...

# %%
df = df.replace('..', np.nan)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Country Name  Year  \
# 0       11160             0     Pakistan  1960
# 1       11161             0     Pakistan  1961
# 2       11162             0     Pakistan  1962
# 3       11163             0     Pakistan  1963
# 4       11164             0     Pakistan  1964
#
#   ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Access to electricity (% of population)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Adjusted net national income (annual % growth)  \
# ...

# %%
df_pak = df[df['Country Name'] == 'Pakistan'].iloc[:,3:]
df_pak.head()
# Out:
#    Year ARI treatment (% of children under 5 taken to a health provider)  \
# 0  1960                                                NaN
# 1  1961                                                NaN
# 2  1962                                                NaN
# 3  1963                                                NaN
# 4  1964                                                NaN
#
#   Access to electricity (% of population)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Adjusted net national income (annual % growth)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# ...

# %%
# %%time
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
df_pak_filled = imputer.fit_transform(df_pak)
# Out:
# CPU times: user 164 ms, sys: 6.21 ms, total: 170 ms
# Wall time: 167 ms

# %%
df_pak_filled_df = pd.DataFrame(data = df_pak_filled)

# %%
df_pak_filled_df
# Out:
#        0          1          2          3          4        5             6    \
# 0   1960.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 1   1961.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 2   1962.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 3   1963.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 4   1964.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 5   1965.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 6   1966.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 7   1967.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 8   1968.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 9   1969.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# 10  1970.0  70.375756   6.451320   3.194313  59.973720    100.0    100.000000
# ...

# %%
df_pak_filled_df.iloc[:,2]
# Out:
# 0      6.451320
# 1      6.451320
# 2      6.451320
# 3      6.451320
# 4      6.451320
# 5      6.451320
# 6      6.451320
# 7      6.451320
# 8      6.451320
# 9      6.451320
# 10     6.451320
# 11     6.451320
# 12     6.451320
# 13     6.451320
# 14     6.451320
# 15     6.451320
# 16     6.451320
# 17     6.451320
# 18     6.451320
# 19     6.451320
# 20     6.451320
# 21     6.451320
# 22     6.451320
# 23     6.451320
# 24     6.451320
# 25     6.451320
# 26     6.451320
# 27    11.290743
# 28     5.065376
# 29     2.997842
# 30     4.272201
# 31     1.344296
# 32     5.605697
# 33     1.345311
# 34     3.576080
# 35     7.679548
# 36     3.416043
# 37     0.534376
# 38     5.949945
# 39     2.372600
# 40    -8.951261
# 41     3.732388
# 42     3.988629
# 43     8.223478
# 44     6.133011
# 45     5.682897
# 46    12.842713
# 47     4.787634
# 48     0.159635
# 49     5.395969
# 50     3.356702
# 51     4.000407
# 52     2.866459
# 53     4.707640
# 54     5.972158
# ...

# %%
df_pak['Access to electricity (% of population)']
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27     11.2907430468447
# 28     5.06537600547345
# 29     2.99784152420581
# 30     4.27220143155806
# 31     1.34429589199527
# 32     5.60569714298613
# 33     1.34531098210753
# 34     3.57608025208262
# 35     7.67954820529559
# 36     3.41604278728052
# 37    0.534375643931668
# ...

# %%
dict = {"First" : [100, 90, np.nan, 95, np.nan], "Second" : [30, 45, 56, np.nan, np.nan], "Third" : [np.nan, 40, 80, 98, np.nan]}
dx = pd.DataFrame(dict)
dx
# Out:
#    First  Second  Third
# 0  100.0    30.0    NaN
# 1   90.0    45.0   40.0
# 2    NaN    56.0   80.0
# 3   95.0     NaN   98.0
# 4    NaN     NaN    NaN

# %%
impx = KNNImputer(n_neighbors=2)
x = imputer.fit_transform(dx)
x
# Out:
# array([[100.        ,  30.        ,  72.66666667],
#        [ 90.        ,  45.        ,  40.        ],
#        [ 95.        ,  56.        ,  80.        ],
#        [ 95.        ,  43.66666667,  98.        ],
#        [ 95.        ,  43.66666667,  72.66666667]])
