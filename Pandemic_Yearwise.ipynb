# %%
import numpy as np
import pandas as pd

# %%
country = ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
       'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
       'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
       'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
       'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
       'Botswana', 'Brazil', 'British Virgin Islands',
       'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
       'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
       'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
       'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
       'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
       'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica',
       'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
       'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
       'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
       'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
       'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
       'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
       'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
       'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
       'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
       'Kiribati', 'Korea, Dem. People’s Rep.', 'Korea, Rep.', 'Kosovo',
       'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon',
       'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
       'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
       'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
       'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
       'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
       'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
       'Niger', 'Nigeria', 'North Macedonia', 'Northern Mariana Islands',
       'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
       'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Seychelles', 'Sierra Leone', 'Singapore',
       'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
       'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
       'St. Martin (French part)', 'St. Vincent and the Grenadines',
       'Sudan', 'Suriname', 'Sweden', 'Switzerland',
       'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
       'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
       'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
       'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
       'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
       'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe',
       'Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)']

# %%
country_last89 = country[-89:]

# %%
pd.set_option('display.max_columns', df.shape[1])

# %%
country_last89
# Out:
# ['Slovak Republic',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Martin (French part)',
#  'St. Vincent and the Grenadines',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela, RB',
#  'Vietnam',
#  'Virgin Islands (U.S.)',
#  'West Bank and Gaza',
#  'Yemen, Rep.',
#  'Zambia',
#  'Zimbabwe',
#  'Arab World',
#  'Caribbean small states',
#  'Central Europe and the Baltics',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
# ...

# %%
df = pd.read_csv('ANNFormat.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name  Year  \
# 0           0  Afghanistan  1960
# 1           0  Afghanistan  1961
# 2           0  Afghanistan  1962
# 3           0  Afghanistan  1963
# 4           0  Afghanistan  1964
#
#   ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of population)  \
# 0                                      ..
# 1                                      ..
# 2                                      ..
# 3                                      ..
# 4                                      ..
#
#   Adjusted net national income (annual % growth)  \
# 0                                             ..
# 1                                             ..
# ...

# %%
df_slovak = df[df['Country Name'] == 'Slovak Republic']

# %%
#Slovak Republic/Slovakia
pandemic = []
for i in range(df_slovak.shape[0]):
    pandemic.append(0)
df_slovak['Pandemic'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_ann_format = df_ann_format.append(df_slovak)
df_ann_format.shape
# Out:
# (1380, 145)

# %%
df_years['Slovak Republic'] = list(df_slovak.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_slovak = df_slovak.rename(columns = {"Pandemic" : "Label"})
df_slovak.head()
# Out:
#        Unnamed: 0     Country Name  Year  \
# 12720           0  Slovak Republic  1960
# 12721           0  Slovak Republic  1961
# 12722           0  Slovak Republic  1962
# 12723           0  Slovak Republic  1963
# 12724           0  Slovak Republic  1964
#
#       ARI treatment (% of children under 5 taken to a health provider)  \
# 12720                                                 ..
# 12721                                                 ..
# 12722                                                 ..
# 12723                                                 ..
# 12724                                                 ..
#
#       Access to electricity (% of population)  \
# 12720                                      ..
# 12721                                      ..
# 12722                                      ..
# 12723                                      ..
# 12724                                      ..
#
#       Adjusted net national income (annual % growth)  \
# ...

# %%
#Slovenia
df_slovenia = df[df['Country Name'] == 'Slovenia']
pandemic = []
for i in range(df_slovenia.shape[0]):
    if(df_slovenia.iloc[i,2] == 2003 or df_slovenia.iloc[i,2] == 2004 or df_slovenia.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_slovenia['Pandemic'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Slovenia'] = list(df_slovenia.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_ann_format = df_ann_format.append(df_slovenia)
df_years['Slovenia'] = list(df_slovenia.loc[:,'Label'])

df_ann_format.shape
# Out:
# (1440, 145)

# %%
df_slovenia = df_slovenia.rename(columns = {"Pandemic" : "Label"})

# %%
#Soloman Islands
df_soloman = df[df['Country Name'] == 'Soloman Islands']
pandemic = []
for i in range(df_soloman.shape[0]):
    pandemic.append(0)
df_soloman['Pandemic'] = pandemic
df_soloman.head()
# Out:
# Empty DataFrame
# ...

# %%
df_ann_format = df_ann_format.append(df_soloman)
df_years['Soloman Islands'] = list(df_soloman.loc[:,'Label'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-279-193994d0df0e> in <module>
#       1 df_ann_format = df_ann_format.append(df_soloman)
# ----> 2 df_years['Soloman Islands'] = list(df_soloman.loc[:,'Label'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3465         else:
#    3466             # set column
# -> 3467             self._set_item(key, value)
#    3468
#    3469     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3542
#    3543         self._ensure_valid_index(value)
# -> 3544         value = self._sanitize_column(key, value)
#    3545         NDFrame._set_item(self, key, value)
#    3546
#
# ...

# %%
df_soloman = df_soloman.rename(columns = {"Pandemic" : "Label"})

# %%
#Somalia
df_somalia = df[df['Country Name'] == 'Somalia']
pandemic = []
for i in range(df_somalia.shape[0]):
    if(df_somalia.iloc[i,2] == 1983 or df_somalia.iloc[i,2] == 1989 or df_somalia.iloc[i,2] == 1971
       or df_somalia.iloc[i,2] == 1988 or df_somalia.iloc[i,2] == 1980
       or df_somalia.iloc[i,2] == 2000 or df_somalia.iloc[i,2] == 2001 or df_somalia.iloc[i,2] == 2002 
       or df_somalia.iloc[i,2] == 2005 or df_somalia.iloc[i,2] == 2006
       or df_somalia.iloc[i,2] == 2007 or df_somalia.iloc[i,2] == 2013 or df_somalia.iloc[i,2] == 2018):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_somalia['Pandemic'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
df_ann_format = df_ann_format.append(df_somalia)
df_years['Somalia'] = list(df_somalia.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_somalia = df_somalia.rename(columns = {"Pandemic" : "Label"})

# %%
#South Africa
df_safrica = df[df['Country Name'] == 'South Africa']
pandemic = []
for i in range(df_safrica.shape[0]):
    if(df_safrica.iloc[i,2] == 1948 or df_safrica.iloc[i,2] == 1956
       or df_safrica.iloc[i,2] == 2000 or df_safrica.iloc[i,2] == 2001 or df_safrica.iloc[i,2] == 2003 
       or df_safrica.iloc[i,2] == 2004 or df_safrica.iloc[i,2] == 2008
       or df_safrica.iloc[i,2] == 2010 or df_safrica.iloc[i,2] == 2018):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_safrica['Pandemic'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
df_ann_format = df_ann_format.append(df_safrica)
df_years['South Africa'] = list(df_safrica.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_safrica = df_safrica.rename(columns = {"Pandemic" : "Label"})

# %%
#South Sudan
df_ssudan = df[df['Country Name'] == 'South Sudan']
pandemic = []
for i in range(df_ssudan.shape[0]):
    if(df_ssudan.iloc[i,2] == 2013
       or df_ssudan.iloc[i,2] == 2014 or df_ssudan.iloc[i,2] == 2016):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_ssudan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_ssudan)
df_years['South Sudan'] = list(df_ssudan.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Spain
df_spain = df[df['Country Name'] == 'Spain']
pandemic = []
for i in range(df_spain.shape[0]):
    if(df_spain.iloc[i,2] == 2000 or df_spain.iloc[i,2] == 2001 or df_spain.iloc[i,2] == 2003 
       or df_spain.iloc[i,2] == 2004 or df_spain.iloc[i,2] == 2013 or df_spain.iloc[i,2] == 2017
       or df_spain.iloc[i,2] == 2014 or df_spain.iloc[i,2] == 2015 or df_spain.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_spain['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_ann_format = df_ann_format.append(df_spain)
df_years['Spain'] = list(df_spain.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Sri Lanka
df_slanka = df[df['Country Name'] == 'Sri Lanka']
pandemic = []
for i in range(df_slanka.shape[0]):
    if(df_slanka.iloc[i,2] == 2005 or df_slanka.iloc[i,2] == 2017 or df_slanka.iloc[i,2] == 1974
      or df_slanka.iloc[i,2] == 1986 or df_slanka.iloc[i,2] == 1982 or df_slanka.iloc[i,2] == 1968
      or df_slanka.iloc[i,2] == 1969 or df_slanka.iloc[i,2] == 2002 or df_slanka.iloc[i,2] == 2009
      or df_slanka.iloc[i,2] == 2012 or df_slanka.iloc[i,2] == 2014):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_slanka['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
df_ann_format = df_ann_format.append(df_slanka)
df_years['Sri Lanka'] = list(df_slanka.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#St. Kitts and Nevis
df_skitts = df[df['Country Name'] == 'St. Kitts and Nevis']
pandemic = []
for i in range(df_skitts.shape[0]):
    pandemic.append(0)
    
df_skitts['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#St. Lucia
df_slucia = df[df['Country Name'] == 'St. Lucia']
pandemic = []
for i in range(df_slucia.shape[0]):
    if(df_slucia.iloc[i,2] == 1981 or df_slucia.iloc[i,2] == 2013 or df_slucia.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
    
df_slucia['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_slucia)
df_years['St. Lucia'] = list(df_slucia.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#St. Martin (French part)
df_smartin = df[df['Country Name'] == 'St. Martin (French part)']
pandemic = []
for i in range(df_smartin.shape[0]):
    if(df_smartin.iloc[i,2] == 2013 or df_smartin.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
    
df_smartin['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_smartin)
df_years['St. Martin (French part)'] = list(df_smartin.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#St. Vincent and the Grenadines
df_svincent = df[df['Country Name'] == 'St. Vincent and the Grenadines']
pandemic = []
for i in range(df_svincent.shape[0]):
    pandemic.append(0)
    
df_svincent['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df_ann_format = df_ann_format.append(df_svincent)
df_years['St. Vincent and the Grenadines)'] = list(df_svincent.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Sudan
df_sudan = df[df['Country Name'] == 'Sudan']
pandemic = []
for i in range(df_sudan.shape[0]):
    if(df_sudan.iloc[i,2] == 1984 or df_sudan.iloc[i,2] == 2000 or df_sudan.iloc[i,2] == 2003 
       or df_sudan.iloc[i,2] == 2004 or df_sudan.iloc[i,2] == 2005 or df_sudan.iloc[i,2] == 2006 
       or df_sudan.iloc[i,2] == 2007
       or df_sudan.iloc[i,2] == 2008 or df_sudan.iloc[i,2] == 2009 or df_sudan.iloc[i,2] == 2012
       or df_sudan.iloc[i,2] == 2013 or df_sudan.iloc[i,2] == 2018 or df_sudan.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_sudan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
df_ann_format = df_ann_format.append(df_sudan)
df_years['Sudan'] = list(df_sudan.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Sudan
df_suriname = df[df['Country Name'] == 'Suriname']
pandemic = []
for i in range(df_suriname.shape[0]):
    if(df_suriname.iloc[i,2] == 2001 
       or df_suriname.iloc[i,2] == 2015 or df_suriname.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_suriname['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_suriname)
df_years['Suriname'] = list(df_suriname.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Sweden
df_sweden = df[df['Country Name'] == 'Sweden']
pandemic = []
for i in range(df_sweden.shape[0]):
    if(df_sweden.iloc[i,2] == 1968 or  df_sweden.iloc[i,2] == 1977 or df_sweden.iloc[i,2] == 2003 or df_sweden.iloc[i,2] == 2004 or df_sweden.iloc[i,2] == 2009
       or df_sweden.iloc[i,2] == 2016 or df_sweden.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_sweden['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_sweden)
df_years['Sweden'] = list(df_sweden.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Switzerland
df_switzerland = df[df['Country Name'] == 'Switzerland']
pandemic = []
for i in range(df_switzerland.shape[0]):
    if(df_switzerland.iloc[i,2] == 2003 or df_switzerland.iloc[i,2] == 2009
       or df_switzerland.iloc[i,2] == 2004 or df_switzerland.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_switzerland['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_switzerland)
df_years['Switzerland'] = list(df_switzerland.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Syrian Arab Republic
df_syria = df[df['Country Name'] == 'Syrian Arab Republic']
pandemic = []
for i in range(df_syria.shape[0]):
    if(df_syria.iloc[i,2] == 2013 or df_syria.iloc[i,2] == 2009
       or df_syria.iloc[i,2] == 2014 or df_syria.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_syria['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_syria)
df_years['Syrian Arab Republic'] = list(df_syria.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Tajikistan
df_tajikistan = df[df['Country Name'] == 'Tajikistan']
pandemic = []
for i in range(df_tajikistan.shape[0]):
    if(df_tajikistan.iloc[i,2] == 2010 or df_tajikistan.iloc[i,2] == 1996):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tajikistan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tajikistan)
df_years['Tajikistan'] = list(df_tajikistan.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Tanzania
df_tanzania = df[df['Country Name'] == 'Tanzania']
pandemic = []
for i in range(df_tanzania.shape[0]):
    if(df_tanzania.iloc[i,2] == 1974 or df_tanzania.iloc[i,2] == 1962 or df_tanzania.iloc[i,2] == 1984):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tanzania['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tanzania)
df_years['Tanzania'] = list(df_tanzania.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Thailand
df_thailand = df[df['Country Name'] == 'Thailand']
pandemic = []
for i in range(df_thailand.shape[0]):
    if(df_thailand.iloc[i,2] == 2003 or df_thailand.iloc[i,2] == 2004 or df_thailand.iloc[i,2] == 2015
      or df_thailand.iloc[i,2] == 2005 or df_thailand.iloc[i,2] == 2006 or df_thailand.iloc[i,2] == 2016
      or df_thailand.iloc[i,2] == 1993 or df_thailand.iloc[i,2] == 1987 or df_thailand.iloc[i,2] == 2000):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_thailand['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_ann_format = df_ann_format.append(df_thailand)
df_years['Thailand'] = list(df_thailand.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Timor-Leste
df_timor = df[df['Country Name'] == 'Timor-Leste']
pandemic = []
for i in range(df_timor.shape[0]):
    if(df_timor.iloc[i,2] == 2005 or df_timor.iloc[i,2] == 2011 or df_timor.iloc[i,2] == 2015):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_timor['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_timor)
df_years['Timor-Leste'] = list(df_timor.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Togo
df_togo = df[df['Country Name'] == 'Togo']
pandemic = []
for i in range(df_togo.shape[0]):
    if(df_togo.iloc[i,2] == 2003 or df_togo.iloc[i,2] == 2007 or df_togo.iloc[i,2] == 2006
      or df_togo.iloc[i,2] == 2016 or df_togo.iloc[i,2] == 2017 or df_togo.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_togo['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_togo)
df_years['Togo'] = list(df_togo.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Tonga
df_tonga = df[df['Country Name'] == 'Tonga']
pandemic = []
for i in range(df_tonga.shape[0]):
    if(df_togo.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tonga['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tonga)
df_years['Tonga'] = list(df_tonga.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Trinidad and Tobago
df_tobago = df[df['Country Name'] == 'Trinidad and Tobago']
pandemic = []
for i in range(df_tobago.shape[0]):
    if(df_tobago.iloc[i,2] == 1996):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tobago['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tobago)
df_years['Tobago'] = list(df_tobago.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Tunisia
df_tunisia = df[df['Country Name'] == 'Tunisia']
pandemic = []
for i in range(df_tunisia.shape[0]):
    if(df_tunisia.iloc[i,2] == 2013):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tunisia['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tunisia)
df_years['Tunisia'] = list(df_tunisia.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Turkey
df_turkey = df[df['Country Name'] == 'Turkey']
pandemic = []
for i in range(df_turkey.shape[0]):
    if(df_turkey.iloc[i,2] == 2005 or df_turkey.iloc[i,2] == 2006 or df_turkey.iloc[i,2] == 2014
      or df_turkey.iloc[i,2] == 1979):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_turkey['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_turkey)
df_years['Turkey'] = list(df_turkey.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Turkmenistan
df_turkmenistan = df[df['Country Name'] == 'Turkmenistan']
pandemic = []
for i in range(df_turkmenistan.shape[0]):
    if(df_turkmenistan.iloc[i,2] == 1998 or df_turkmenistan.iloc[i,2] == 2004):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_turkmenistan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_turkmenistan)
df_years['Turkmenistan'] = list(df_turkmenistan.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Turks and Caicos
df_turks = df[df['Country Name'] == 'Turks and Caicos']
pandemic = []
for i in range(df_turks.shape[0]):
    pandemic.append(0)
df_turks['Label'] = pandemic

# %%
df_ann_format = df_ann_format.append(df_turks)
df_years['Turks and Caicos'] = list(df_turks.loc[:,'Label'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-303-f9400f6d64b6> in <module>
#       1 df_ann_format = df_ann_format.append(df_turks)
# ----> 2 df_years['Turks and Caicos'] = list(df_turks.loc[:,'Label'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3465         else:
#    3466             # set column
# -> 3467             self._set_item(key, value)
#    3468
#    3469     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3542
#    3543         self._ensure_valid_index(value)
# -> 3544         value = self._sanitize_column(key, value)
#    3545         NDFrame._set_item(self, key, value)
#    3546
#
# ...

# %%
#Tuvalu
df_tuvalu = df[df['Country Name'] == 'Tuvalu']
pandemic = []
for i in range(df_tuvalu.shape[0]):
    if(df_tuvalu.iloc[i,2] == 2019 or df_tuvalu.iloc[i,2] == 2014 or df_tuvalu.iloc[i,2] == 1975):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_tuvalu['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_tuvalu)
df_years['Tuvalu'] = list(df_tuvalu.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Uganda
df_uganda = df[df['Country Name'] == 'Uganda']
pandemic = []
for i in range(df_uganda.shape[0]):
    if(df_uganda.iloc[i,2] == 2019 or df_uganda.iloc[i,2] == 2014 or df_tuvalu.iloc[i,2] == 1975):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_uganda['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_uganda)
df_years['Uganda'] = list(df_uganda.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Ukraine
df_ukraine = df[df['Country Name'] == 'Ukraine']
pandemic = []
for i in range(df_ukraine.shape[0]):
    if(df_ukraine.iloc[i,2] == 2003 or df_ukraine.iloc[i,2] == 2004 or df_ukraine.iloc[i,2] == 2015 or df_ukraine.iloc[i,2] == 2016):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_ukraine['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_ukraine)
df_years['Ukraine'] = list(df_ukraine.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#United Arab Emirates
df_uae = df[df['Country Name'] == 'United Arab Emirates']
pandemic = []
for i in range(df_uae.shape[0]):
    if(df_uae.iloc[i,2] == 2013 or df_uae.iloc[i,2] == 2014 or df_uae.iloc[i,2] == 2015 or df_uae.iloc[i,2] == 2016
      or df_uae.iloc[i,2] == 2017 or df_uae.iloc[i,2] == 2018 or df_uae.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_uae['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_uae)
df_years['United Arab Emirates'] = list(df_uae.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#United Arab Emirates
df_uk = df[df['Country Name'] == 'United Kingdom']
pandemic = []
for i in range(df_uae.shape[0]):
    if(df_uk.iloc[i,2] == 2000 or df_uk.iloc[i,2] == 2001 or df_uk.iloc[i,2] == 2003 or df_uk.iloc[i,2] == 2004
      or df_uk.iloc[i,2] == 2007 or df_uk.iloc[i,2] == 2012 or df_uk.iloc[i,2] == 2013 or df_uk.iloc[i,2] == 2014
      or df_uk.iloc[i,2] == 2016 or df_uk.iloc[i,2] == 2017 or df_uk.iloc[i,2] == 2019 or df_uk.iloc[i,2] == 1997):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_uk['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_ann_format = df_ann_format.append(df_uk)
df_years['United Kingdom'] = list(df_uk.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#United States
df_us = df[df['Country Name'] == 'United States']
pandemic = []
for i in range(df_us.shape[0]):
    if(df_us.iloc[i,2] == 2000 or df_us.iloc[i,2] == 2001 or df_us.iloc[i,2] == 2003 or df_us.iloc[i,2] == 2004
      or df_us.iloc[i,2] == 2007 or df_us.iloc[i,2] == 2012 or df_us.iloc[i,2] == 2015 or df_us.iloc[i,2] == 2014
      or df_us.iloc[i,2] == 2016 or df_us.iloc[i,2] == 2017 or df_us.iloc[i,2] == 1981 or df_us.iloc[i,2] == 1993
      or df_us.iloc[i,2] == 2009 or df_us.iloc[i,2] == 2010 or df_us.iloc[i,2] == 2016
      or df_us.iloc[i,2] == 2002 or df_us.iloc[i,2] == 2006 or df_us.iloc[i,2] == 2011):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_us['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
df_ann_format = df_ann_format.append(df_us)
df_years['United States'] = list(df_us.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Uruguay
df_uruguay = df[df['Country Name'] == 'Uruguay']
pandemic = []
for i in range(df_uruguay.shape[0]):
    pandemic.append(0)
df_uruguay['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_ann_format = df_ann_format.append(df_uruguay)
df_years['Uruguay'] = list(df_uruguay.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Uzbekistan
df_uzbekistan = df[df['Country Name'] == 'Uzbekistan']
pandemic = []
for i in range(df_uzbekistan.shape[0]):
    if(df_us.iloc[i,2] == 1993):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_uzbekistan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_uzbekistan)
df_years['Uzbekistan'] = list(df_uzbekistan.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Vanuatu
df_vanuatu = df[df['Country Name'] == 'Vanuatu']
pandemic = []
for i in range(df_vanuatu.shape[0]):
    if(df_vanuatu.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_vanuatu['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_vanuatu)
df_years['Vanuatu'] = list(df_vanuatu.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Venezuela
df_venezuela = df[df['Country Name'] == 'Venezuela']
pandemic = []
for i in range(df_venezuela.shape[0]):
    if(df_venezuela.iloc[i,2] == 2004 or df_venezuela.iloc[i,2] == 2015 or df_venezuela.iloc[i,2] == 2016
      or df_venezuela.iloc[i,2] == 2019 or df_venezuela.iloc[i,2] == 1992 or df_venezuela.iloc[i,2] == 2014):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_venezuela['Label'] = pandemic

# %%
df_ann_format = df_ann_format.append(df_venezuela)
df_years['Venezuela'] = list(df_venezuela.loc[:,'Label'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-314-511ea8944f21> in <module>
#       1 df_ann_format = df_ann_format.append(df_venezuela)
# ----> 2 df_years['Venezuela'] = list(df_venezuela.loc[:,'Label'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3465         else:
#    3466             # set column
# -> 3467             self._set_item(key, value)
#    3468
#    3469     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3542
#    3543         self._ensure_valid_index(value)
# -> 3544         value = self._sanitize_column(key, value)
#    3545         NDFrame._set_item(self, key, value)
#    3546
#
# ...

# %%
#Vietnam
df_vietnam = df[df['Country Name'] == 'Vietnam']
pandemic = []
for i in range(df_vietnam.shape[0]):
    if(df_vietnam.iloc[i,2] == 2003 or df_vietnam.iloc[i,2] == 2004 or df_vietnam.iloc[i,2] == 2005
      or df_vietnam.iloc[i,2] == 2010 or df_vietnam.iloc[i,2] == 2012 or df_vietnam.iloc[i,2] == 2016
      or df_vietnam.iloc[i,2] == 1967):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_vietnam['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_ann_format = df_ann_format.append(df_vietnam)
df_years['Vietnam'] = list(df_vietnam.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Virgin Islands
df_visland = df[df['Country Name'] == 'Virgin Islands']
pandemic = []
for i in range(df_visland.shape[0]):
    pandemic.append(0)
df_visland['Label'] = pandemic

# %%
#West Bank and Gaza
df_wbank = df[df['Country Name'] == 'West Bank and Gaza']
pandemic = []
for i in range(df_wbank.shape[0]):
    if(df_wbank.iloc[i,2] == 1991):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_wbank['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_ann_format = df_ann_format.append(df_wbank)
df_years['Wbank'] = list(df_wbank.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Yemen
df_yemen = df[df['Country Name'] == 'Yemen, Rep.']
pandemic = []
for i in range(df_yemen.shape[0]):
    if(df_yemen.iloc[i,2] == 2000 or df_yemen.iloc[i,2] == 2005 or df_yemen.iloc[i,2] == 2014 or df_yemen.iloc[i,2] == 2017
      or df_yemen.iloc[i,2] == 2016):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_yemen['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_yemen)
df_years['Yemen'] = list(df_yemen.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Zambia
df_zambia = df[df['Country Name'] == 'Zambia']
pandemic = []
for i in range(df_zambia.shape[0]):
    if(df_zambia.iloc[i,2] == 2001 or df_zambia.iloc[i,2] == 2003 or df_zambia.iloc[i,2] == 2004 
       or df_zambia.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_zambia['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_zambia)
df_years['Zambia'] = list(df_zambia.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Zimbabwe
df_zimbabwe = df[df['Country Name'] == 'Zimbabwe']
pandemic = []
for i in range(df_zimbabwe.shape[0]):
    if(df_zimbabwe.iloc[i,2] == 1997 or df_zimbabwe.iloc[i,2] == 1998 or df_zimbabwe.iloc[i,2] == 1999 
       or df_zimbabwe.iloc[i,2] == 2008 or df_zimbabwe.iloc[i,2] == 2009 or df_zimbabwe.iloc[i,2] == 1974):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_zimbabwe['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ann_format = df_ann_format.append(df_zimbabwe)
df_years['Zimbabwe'] = list(df_zimbabwe.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_ann_format.shape
# Out:
# (3660, 145)

# %%
df_ann_format.to_csv('Last_89_ANNFormat.csv')

# %%
df_years.to_csv('Last_89.csv')

# %%
df_zimbabwe.head()
# Out:
#        Unnamed: 0 Country Name  Year  \
# 15780           0     Zimbabwe  1960
# 15781           0     Zimbabwe  1961
# 15782           0     Zimbabwe  1962
# 15783           0     Zimbabwe  1963
# 15784           0     Zimbabwe  1964
#
#       ARI treatment (% of children under 5 taken to a health provider)  \
# 15780                                                 ..
# 15781                                                 ..
# 15782                                                 ..
# 15783                                                 ..
# 15784                                                 ..
#
#       Access to electricity (% of population)  \
# 15780                                      ..
# 15781                                      ..
# 15782                                      ..
# 15783                                      ..
# 15784                                      ..
#
#       Adjusted net national income (annual % growth)  \
# ...

# %%
#Pakistan
df_pakistan = df[df['Country Name'] == 'Pakistan']
pandemic = []
for i in range(df_pakistan.shape[0]):
    if(df_pakistan.iloc[i,2] == 2002 or df_pakistan.iloc[i,2] == 2008 or df_pakistan.iloc[i,2] == 2007 
       or df_pakistan.iloc[i,2] == 2010 or df_pakistan.iloc[i,2] == 2011 or df_pakistan.iloc[i,2] == 2016
      or df_pakistan.iloc[i,2] == 2019 or df_pakistan.iloc[i,2] == 2012 or df_pakistan.iloc[i,2] == 2006):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_pakistan['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Palau'] = list(df_palau.loc[:,'Label'])
df_years.head()

#df_ann_format = df_pakistan
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau
# 12600  1960         0      0
# 12601  1961         0      0
# 12602  1962         0      0
# 12603  1963         0      0
# 12604  1964         0      0

# %%
df_ann_format = df_ann_format.append(df_palau)
df_ann_format.shape
# Out:
# (120, 145)

# %%
#Palau
df_palau = df[df['Country Name'] == 'Palau']
pandemic = []
for i in range(df_palau.shape[0]):
    if(df_palau.iloc[i,2] == 2018 or df_palau.iloc[i,2] == 2001):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_palau['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#Panama
df_panama = df[df['Country Name'] == 'Panama']
pandemic = []
for i in range(df_panama.shape[0]):
    if(df_panama.iloc[i,2] == 2000 or df_panama.iloc[i,2] == 2015 or df_panama.iloc[i,2] == 2016
      or df_panama.iloc[i,2] == 1991 or df_panama.iloc[i,2] == 1995 or df_panama.iloc[i,2] == 1997 or
      df_panama.iloc[i,2] == 1999):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_panama['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Panama'] = list(df_panama.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama
# 12600  1960         0      0       0
# 12601  1961         0      0       0
# 12602  1962         0      0       0
# 12603  1963         0      0       0
# 12604  1964         0      0       0

# %%
df_ann_format = df_ann_format.append(df_panama)
df_ann_format.shape
# Out:
# (180, 145)

# %%
#Papua New Guinea
df_papa = df[df['Country Name'] == 'Papua New Guinea']
pandemic = []
for i in range(df_papa.shape[0]):
    if(df_papa.iloc[i,2] == 2019 or df_papa.iloc[i,2] == 2009 or df_papa.iloc[i,2] == 1960):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_papa['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Papua New Guinea'] = list(df_papa.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea
# 12600  1960         0      0       0                 1
# 12601  1961         0      0       0                 0
# 12602  1962         0      0       0                 0
# 12603  1963         0      0       0                 0
# 12604  1964         0      0       0                 0

# %%
df_ann_format = df_ann_format.append(df_papa)
df_ann_format.shape
# Out:
# (240, 145)

# %%
#Paraguay
df_paraguay = df[df['Country Name'] == 'Paraguay']
pandemic = []
for i in range(df_paraguay.shape[0]):
    if(df_paraguay.iloc[i,2] == 2015 or df_paraguay.iloc[i,2] == 2008 or df_paraguay.iloc[i,2] == 2013
      or df_paraguay.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_paraguay['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Paraguay'] = list(df_paraguay.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay
# 12600  1960         0      0       0                 1         0
# 12601  1961         0      0       0                 0         0
# 12602  1962         0      0       0                 0         0
# 12603  1963         0      0       0                 0         0
# 12604  1964         0      0       0                 0         0

# %%
df_ann_format = df_ann_format.append(df_paraguay)
df_ann_format.shape
# Out:
# (300, 145)

# %%
#Peru
df_peru = df[df['Country Name'] == 'Peru']
pandemic = []
for i in range(df_peru.shape[0]):
    if(df_peru.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_peru['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Peru'] = list(df_peru.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0

# %%
df_ann_format = df_ann_format.append(df_peru)
df_ann_format.shape
# Out:
# (360, 145)

# %%
#Philippines
df_philippines = df[df['Country Name'] == 'Philippines']
pandemic = []
for i in range(df_philippines.shape[0]):
    if(df_philippines.iloc[i,2] == 2003 or df_philippines.iloc[i,2] == 2005 or df_philippines.iloc[i,2] == 2009
      or df_philippines.iloc[i,2] == 2015 or df_philippines.iloc[i,2] == 2019 or df_philippines.iloc[i,2] == 1961
      or df_philippines.iloc[i,2] == 1968):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_philippines['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Philippines'] = list(df_philippines.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines
# 12600            0
# 12601            1
# 12602            0
# 12603            0
# ...

# %%
df_ann_format = df_ann_format.append(df_philippines)
df_ann_format.shape
# Out:
# (420, 145)

# %%
#Poland
df_poland = df[df['Country Name'] == 'Poland']
pandemic = []
for i in range(df_poland.shape[0]):
    if(df_poland.iloc[i,2] == 2003 or df_poland.iloc[i,2] == 1961):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_poland['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Poland'] = list(df_poland.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland
# 12600            0       0
# 12601            1       1
# 12602            0       0
# ...

# %%
df_ann_format = df_ann_format.append(df_poland)
df_ann_format.shape
# Out:
# (480, 145)

# %%
#Portugal
df_portugal = df[df['Country Name'] == 'Portugal']
pandemic = []
for i in range(df_portugal.shape[0]):
    if(df_portugal.iloc[i,2] == 2003 or df_portugal.iloc[i,2] == 2004 or df_portugal.iloc[i,2] == 2012
      or df_portugal.iloc[i,2] == 2014 or df_portugal.iloc[i,2] == 2015 or df_portugal.iloc[i,2] == 2017
      or df_portugal.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_portugal['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Portugal'] = list(df_portugal.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal
# 12600            0       0         0
# 12601            1       1         0
# ...

# %%
df_ann_format = df_ann_format.append(df_portugal)
df_ann_format.shape
# Out:
# (540, 145)

# %%
#Puerto Rico
df_puerto = df[df['Country Name'] == 'Puerto Rico']
pandemic = []
for i in range(df_puerto.shape[0]):
    if(df_puerto.iloc[i,2] == 1960 or df_puerto.iloc[i,2] == 1977 or df_puerto.iloc[i,2] == 1994
      or df_puerto.iloc[i,2] == 2012 or df_puerto.iloc[i,2] == 2015 or df_puerto.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_puerto['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Puerti Rico'] = list(df_puerto.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico
# 12600            0       0         0            1
# ...

# %%
df_ann_format = df_ann_format.append(df_puerto)
df_ann_format.shape
# Out:
# (600, 145)

# %%
#Qatar
df_qatar = df[df['Country Name'] == 'Qatar']
pandemic = []
for i in range(df_qatar.shape[0]):
    if(df_qatar.iloc[i,2] == 2012 or df_qatar.iloc[i,2] == 2013 or df_qatar.iloc[i,2] == 2014
      or df_qatar.iloc[i,2] == 2015 or df_qatar.iloc[i,2] == 2016 or df_qatar.iloc[i,2] == 2017):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_qatar['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Qatar'] = list(df_qatar.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar
# 12600            0       0         0            1      0
# ...

# %%
df_ann_format = df_ann_format.append(df_qatar)
df_ann_format.shape
# Out:
# (660, 145)

# %%
#Romania
df_romania = df[df['Country Name'] == 'Romania']
pandemic = []
for i in range(df_romania.shape[0]):
    if(df_romania.iloc[i,2] == 2003 or df_romania.iloc[i,2] == 2004 or df_romania.iloc[i,2] == 2005
      or df_romania.iloc[i,2] == 1982 or df_romania.iloc[i,2] == 1986 or df_romania.iloc[i,2] == 1993
      or df_romania.iloc[i,2] == 1997 or df_romania.iloc[i,2] == 2011 or df_romania.iloc[i,2] == 2016):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_romania['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Romania'] = list(df_romania.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania
# ...

# %%
df_ann_format = df_ann_format.append(df_romania)
df_ann_format.shape
# Out:
# (720, 145)

# %%
#Russian Federation
df_russia = df[df['Country Name'] == 'Russian Federation']
pandemic = []
for i in range(df_russia.shape[0]):
    if(df_russia.iloc[i,2] == 2000 or df_russia.iloc[i,2] == 2003 or df_russia.iloc[i,2] == 2005
      or df_russia.iloc[i,2] == 2004 or df_russia.iloc[i,2] == 2010 or df_russia.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_russia['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Russian Federation'] = list(df_russia.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_russia)
df_ann_format.shape
# Out:
# (780, 145)

# %%
#Rwanda
df_rwanda = df[df['Country Name'] == 'Rwanda']
pandemic = []
for i in range(df_rwanda.shape[0]):
    if(df_rwanda.iloc[i,2] == 2000 or df_rwanda.iloc[i,2] == 2002 or df_rwanda.iloc[i,2] == 1994
      or df_rwanda.iloc[i,2] == 2012 or df_rwanda.iloc[i,2] == 2018 or df_rwanda.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_rwanda['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Rwanda'] = list(df_rwanda.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_rwanda)
df_ann_format.shape
# Out:
# (840, 145)

# %%
#Samoa
df_samoa = df[df['Country Name'] == 'Samoa']
pandemic = []
for i in range(df_samoa.shape[0]):
    if(df_samoa.iloc[i,2] == 2019 or df_samoa.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_samoa['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Samoa'] = list(df_samoa.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_samoa)
df_ann_format.shape
# Out:
# (900, 145)

# %%
#Sao Tome and Principe
df_saotome = df[df['Country Name'] == 'Sao Tome and Principe']
pandemic = []
for i in range(df_saotome.shape[0]):
    if(df_saotome.iloc[i,2] == 2004 or df_saotome.iloc[i,2] == 1986):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_saotome['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Sao Tome and Principe'] = list(df_saotome.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_ann_format = df_ann_format.append(df_saotome)
df_ann_format.shape
# Out:
# (960, 145)

# %%
#Saudi Arabia
df_saudi = df[df['Country Name'] == 'Saudi Arabia']
pandemic = []
for i in range(df_saudi.shape[0]):
    if(df_saudi.iloc[i,2] == 2000 or df_saudi.iloc[i,2] == 2001 or df_saudi.iloc[i,2] == 2012
      or df_saudi.iloc[i,2] == 2013 or df_saudi.iloc[i,2] == 2014 or df_saudi.iloc[i,2] == 2015
      or df_saudi.iloc[i,2] == 2016 or df_saudi.iloc[i,2] == 2017 or df_saudi.iloc[i,2] == 2018
      or df_saudi.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_saudi['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
df_years['Saudi Arabia'] = list(df_saudi.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_saudi)
df_ann_format.shape
# Out:
# (1020, 145)

# %%
#Senegal
df_senegal = df[df['Country Name'] == 'Senegal']
pandemic = []
for i in range(df_senegal.shape[0]):
    if(df_senegal.iloc[i,2] == 2002 or df_senegal.iloc[i,2] == 2004 or df_senegal.iloc[i,2] == 2005
      or df_senegal.iloc[i,2] == 2008 or df_senegal.iloc[i,2] == 2010 or df_senegal.iloc[i,2] == 2011
      or df_senegal.iloc[i,2] == 2014 or df_senegal.iloc[i,2] == 2015 or df_senegal.iloc[i,2] == 1988
      or df_senegal.iloc[i,2] == 2019):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_senegal['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
df_years['Senegal'] = list(df_senegal.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_senegal)
df_ann_format.shape
# Out:
# (1080, 145)

# %%
#Serbia
df_serbia = df[df['Country Name'] == 'Serbia']
pandemic = []
for i in range(df_serbia.shape[0]):
    if(df_serbia.iloc[i,2] == 1972 or df_serbia.iloc[i,2] == 2007 or df_serbia.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_serbia['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_years['Serbia'] = list(df_serbia.loc[:,'Label'])
df_years.head()
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Pakistan  Palau  Panama  Papua New Guinea  Paraguay  Peru  \
# 12600  1960         0      0       0                 1         0     0
# 12601  1961         0      0       0                 0         0     0
# 12602  1962         0      0       0                 0         0     0
# 12603  1963         0      0       0                 0         0     0
# 12604  1964         0      0       0                 0         0     0
#
#        Philippines  Poland  Portugal  Puerti Rico  Qatar  Romania  \
# ...

# %%
df_ann_format = df_ann_format.append(df_serbia)
df_ann_format.shape
# Out:
# (1140, 145)

# %%
#Seychelles
df_seychelles = df[df['Country Name'] == 'Seychelles']
pandemic = []
for i in range(df_seychelles.shape[0]):
    if(df_seychelles.iloc[i,2] == 2006 or df_seychelles.iloc[i,2] == 2017 or df_seychelles.iloc[i,2] == 2009
      or df_seychelles.iloc[i,2] == 2017 or df_seychelles.iloc[i,2] == 1960):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_seychelles['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Seychelles'] = list(df_seychelles.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_ann_format = df_ann_format.append(df_seychelles)
df_ann_format.shape
# Out:
# (1200, 145)

# %%
df_ann_format = df_ann_format.append(df_sunny)
df_ann_format.shape
# Out:
# (1260, 145)

# %%
#Sunny
df_sunny = df[df['Country Name'] == 'Sierra Leone']
pandemic = []
for i in range(df_sunny.shape[0]):
    if(df_sunny.iloc[i,2] == 2000 or df_sunny.iloc[i,2] == 2003 or df_sunny.iloc[i,2] == 2004
      or df_sunny.iloc[i,2] == 2009 or df_sunny.iloc[i,2] == 2011 or df_sunny.iloc[i,2] == 2012
      or df_sunny.iloc[i,2] == 2014 or df_sunny.iloc[i,2] == 2019 or df_sunny.iloc[i,2] == 1960):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_sunny['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_years['Sierra Leone'] = list(df_sunny.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#Singapore
df_sing = df[df['Country Name'] == 'Singapore']
pandemic = []
for i in range(df_sing.shape[0]):
    if(df_sing.iloc[i,2] == 2000 or df_sing.iloc[i,2] == 2001 or df_sing.iloc[i,2] == 2003
      or df_sing.iloc[i,2] == 2019 or df_sing.iloc[i,2] == 2009):
        pandemic.append(1)
    else:
        pandemic.append(0)
df_sing['Label'] = pandemic
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_years['Singapore'] = list(df_sing.loc[:,'Label'])
# Out:
# /Users/saloniparekh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_ann_format = df_ann_format.append(df_sing)
df_ann_format.shape
# Out:
# (1320, 145)

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name  Year  \
# 0           0  Afghanistan  1960
# 1           0  Afghanistan  1961
# 2           0  Afghanistan  1962
# 3           0  Afghanistan  1963
# 4           0  Afghanistan  1964
#
#   ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of population)  \
# 0                                      ..
# 1                                      ..
# 2                                      ..
# 3                                      ..
# 4                                      ..
#
#   Adjusted net national income (annual % growth)  \
# 0                                             ..
# 1                                             ..
# ...

# %%
df_years = df_sing[['Year']]
df_years.head()
# Out:
#        Year
# 12600  1960
# 12601  1961
# 12602  1962
# 12603  1963
# 12604  1964
